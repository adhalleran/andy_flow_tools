# %%
# Standard imports 
import collections
import glob
import os
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.backends.backend_pdf import PdfPages
import scipy.stats as stats
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
from cycler import cycler
import numpy as np

# Formatting to make the plots look a bit nicer. 
sns.set_context("talk", font_scale=1.5, rc={"lines.linewidth": 3.0})
sns.set_style("ticks")
sns.set_style({"xtick.direction": "in","ytick.direction": "in"})
mpl.rc('axes', prop_cycle=(cycler('color', ['r', 'k', 'b','g','y','m','c']) ))
mpl.rc('text', usetex=False)
#mpl.rc('font',**{'family':'sans-serif','sans-serif':['HelveticaNeueThin']})
#plt.tick_params(top=False, bottom=False, right=False, left=False)
tw = 1.5
sns.set_style({"xtick.major.size": 6, "ytick.major.size": 6,
               "xtick.minor.size": 4, "ytick.minor.size": 4,
               'axes.labelsize': 24,
               'xtick.major.width': tw, 'xtick.minor.width': tw,
               'ytick.major.width': tw, 'ytick.minor.width': tw})

mpl.rc('xtick', labelsize=18) 
mpl.rc('ytick', labelsize=18)
mpl.rc('axes', linewidth=1.75)
plt.gcf().subplots_adjust(bottom=0.15)
sns.set_style({'axes.labelsize': 24})


def gate(data, firstChannel, secondChannel, lowPercentile, highPercentile):
	""" Filter (gate) cells based on a percentile gating method. This function
		takes the intersection of cells that are within the lowPercentile and
		highPercentile you set for both channels and returns those cells for 
		further analysis. """

	first = np.array(data[firstChannel])
	second = np.array(data[secondChannel])

	firstLow = np.percentile(first, lowPercentile)
	firstHigh = np.percentile(first, highPercentile)
	secondLow = np.percentile(second, lowPercentile)
	secondHigh = np.percentile(second, highPercentile)

	zipped = zip(first, second) 

	gated = []
	ungated = []

	gatingResults = []
	for entry in zipped: 
		if firstLow < entry[0] < firstHigh: 
			if secondLow < entry[1] < secondHigh: 
				gated.append(entry) 
				gatingResults.append(1)
			else: 
				ungated.append(entry)
				gatingResults.append(0)
		else:
			ungated.append(entry)
			gatingResults.append(0)

	gatingResults = np.array(gatingResults)

	data['Gates'] = gatingResults

	return data


def getGates(data, low_percentile, high_percentile):
    """ Main function used in the script. It takes data, a csv file location
    with your data in tidy format, label, what you want the data labeled as on 
    your final plot, and color, what color you want the data to be on the plot. """

    # Read in the data
    df = pd.read_csv(data)
    # Set a mask to remove all cells below 100 Syto62 (a good threshold for dust). 
    #mask0 = df['mKate/APC-A'] > 100
    # Get the intersection of cells on Syto62 and SSC-A.
    gatedOutput = gate(df, 'FSC-A', 'SSC-A', low_percentile, high_percentile)
    return gatedOutput

def plotGating(data, output_name, output_directory, lowPercentile, highPercentile):
    """ This function is if you want to check what your gating looks like. 
    It is a good idea to run this a few times per dataset to make sure all of the
    flow cytometry data looks accurate. It defaults to assume you want to gate on
    mKate/APC-A and SSC-A, as these are the most likely to be used for 
    "quality assurance." 
    Before filtering by the percentile intersection, it removes all cells below
    100 Syto62 signal."""
    df = pd.read_csv(data)
    #mask0 = df['mKate/APC-A'] > 100
    gatedOutput = gate(df, 'FSC-A', 'SSC-A',
        lowPercentile, highPercentile)
    mask = gatedOutput['Gates'] == 1
    
    plt.figure(figsize=(8,8))
    plt.loglog(df['FSC-A'], df['SSC-A'], '.', 
        markersize=6, rasterized=True, color='k')
    plt.loglog(gatedOutput[~mask]['FSC-A'], gatedOutput[~mask]['SSC-A'], '.',
    markersize=6, rasterized=True, color='k', basex=10, basey=10)
    plt.loglog(gatedOutput[mask]['FSC-A'], gatedOutput[mask]['SSC-A'], '.',
        markersize=6, rasterized=True, color='b', basex=10, basey=10)
    plt.ylabel('SSC')
    plt.xlabel('FSC')
    plt.savefig(output_directory + output_name + '.png')
    
def generate_csv_with_gates(file_name, output_name, plot_output_name, output_directory,
                           low_percentile, high_percentile):
    print('file_name = ', file_name)
    print('output_name = ', output_name)
    data = getGates(file_name, low_percentile, high_percentile)
    plotGating(file_name, output_name, plot_output_name, low_percentile, high_percentile)
    data_gated = data.loc[(data['Gates'] == 1) & (data['GFP/FITC-A'] > 0)]
    data_gated.to_csv(output_directory + output_name + '.csv', index=False)

# %%
wells = ['A01', 'B01', 'C01', 'D01', 'E01', 'F01', 'G01', 'H01',
         'A02', 'B02', 'C02', 'D02', 'E02', 'F02', 'G02', 'H02',
         'A03', 'B03', 'C03', 'D03', 'E03', 'F03', 'G03', 'H03',
         'A04', 'B04', 'C04', 'D04', 'E04', 'F04', 'G04', 'H04',
         'A05', 'B05', 'C05', 'D05', 'E05', 'F05', 'G05', 'H05',
         'A06', 'B06', 'C06', 'D06', 'E06', 'F06', 'G06', 'H06',
         'A07', 'B07', 'C07', 'D07', 'E07', 'F07', 'G07', 'H07',
         'A08', 'B08', 'C08', 'D08', 'E08', 'F08', 'G08', 'H08',
         'A09', 'B09', 'C09', 'D09', 'E09', 'F09', 'G09', 'H09',
         'A10', 'B10', 'C10', 'D10', 'E10', 'F10', 'G10', 'H10',
         'A11', 'B11', 'C11', 'D11', 'E11', 'F11', 'G11', 'H11',
         'A12', 'B12', 'C12', 'D12', 'E12', 'F12', 'G12', 'H12']

# %%
def get_all_gates(file_directory, output_directory, plot_output_name,
                  low_percentile, high_percentile):
    all_files = glob.glob(file_directory)
    all_files.sort()
    for i in range(0, len(all_files)):
        generate_csv_with_gates(all_files[i], wells[i],
                                plot_output_name, output_directory, low_percentile,
                               high_percentile)

# %%
import time

# %%
start = time.time()
get_all_gates('../Data/Flow/181010_HCK_dif_burden_G4/tidy/*.csv',
              '../Data/Flow/181010_HCK_dif_burden_G4/gated_scatter/',
              '../Data/Flow/181010_HCK_dif_burden_G4/gates_scatter/',
             40, 90)
end = time.time()
print(end-start)
# Out:
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0001.fcs_tidied.csv
# output_name =  A01
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0002.fcs_tidied.csv
# output_name =  B01
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0003.fcs_tidied.csv
# output_name =  C01
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0004.fcs_tidied.csv
# output_name =  D01
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0005.fcs_tidied.csv
# output_name =  E01
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0006.fcs_tidied.csv
# output_name =  F01
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0007.fcs_tidied.csv
# output_name =  G01
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0008.fcs_tidied.csv
# output_name =  H01
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0009.fcs_tidied.csv
# output_name =  A02
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0010.fcs_tidied.csv
# output_name =  B02
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0011.fcs_tidied.csv
# output_name =  C02
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0012.fcs_tidied.csv
# output_name =  D02
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0013.fcs_tidied.csv
# output_name =  E02
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0014.fcs_tidied.csv
# output_name =  F02
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0015.fcs_tidied.csv
# output_name =  G02
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0016.fcs_tidied.csv
# output_name =  H02
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0017.fcs_tidied.csv
# output_name =  A03
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0018.fcs_tidied.csv
# output_name =  B03
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0019.fcs_tidied.csv
# output_name =  C03
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0020.fcs_tidied.csv
# output_name =  D03
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0021.fcs_tidied.csv
# output_name =  E03
# /Users/andrewhalleran/anaconda/lib/python3.5/site-packages/matplotlib/pyplot.py:537: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0022.fcs_tidied.csv
# output_name =  F03
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0023.fcs_tidied.csv
# output_name =  G03
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0024.fcs_tidied.csv
# output_name =  H03
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0025.fcs_tidied.csv
# output_name =  A04
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0026.fcs_tidied.csv
# output_name =  B04
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0027.fcs_tidied.csv
# output_name =  C04
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0028.fcs_tidied.csv
# output_name =  D04
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0029.fcs_tidied.csv
# output_name =  E04
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0030.fcs_tidied.csv
# output_name =  F04
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0031.fcs_tidied.csv
# output_name =  G04
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0032.fcs_tidied.csv
# output_name =  H04
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0033.fcs_tidied.csv
# output_name =  A05
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0034.fcs_tidied.csv
# output_name =  B05
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0035.fcs_tidied.csv
# output_name =  C05
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0036.fcs_tidied.csv
# output_name =  D05
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0037.fcs_tidied.csv
# output_name =  E05
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0038.fcs_tidied.csv
# output_name =  F05
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0039.fcs_tidied.csv
# output_name =  G05
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0040.fcs_tidied.csv
# output_name =  H05
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0041.fcs_tidied.csv
# output_name =  A06
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0042.fcs_tidied.csv
# output_name =  B06
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0043.fcs_tidied.csv
# output_name =  C06
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0044.fcs_tidied.csv
# output_name =  D06
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0045.fcs_tidied.csv
# output_name =  E06
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0046.fcs_tidied.csv
# output_name =  F06
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0047.fcs_tidied.csv
# output_name =  G06
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0048.fcs_tidied.csv
# output_name =  H06
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0049.fcs_tidied.csv
# output_name =  A07
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0050.fcs_tidied.csv
# output_name =  B07
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0051.fcs_tidied.csv
# output_name =  C07
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0052.fcs_tidied.csv
# output_name =  D07
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0053.fcs_tidied.csv
# output_name =  E07
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0054.fcs_tidied.csv
# output_name =  F07
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0055.fcs_tidied.csv
# output_name =  G07
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0056.fcs_tidied.csv
# output_name =  H07
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0057.fcs_tidied.csv
# output_name =  A08
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0058.fcs_tidied.csv
# output_name =  B08
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0059.fcs_tidied.csv
# output_name =  C08
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0060.fcs_tidied.csv
# output_name =  D08
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0061.fcs_tidied.csv
# output_name =  E08
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0062.fcs_tidied.csv
# output_name =  F08
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0063.fcs_tidied.csv
# output_name =  G08
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0064.fcs_tidied.csv
# output_name =  H08
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0065.fcs_tidied.csv
# output_name =  A09
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0066.fcs_tidied.csv
# output_name =  B09
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0067.fcs_tidied.csv
# output_name =  C09
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0068.fcs_tidied.csv
# output_name =  D09
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0069.fcs_tidied.csv
# output_name =  E09
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0070.fcs_tidied.csv
# output_name =  F09
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0071.fcs_tidied.csv
# output_name =  G09
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0072.fcs_tidied.csv
# output_name =  H09
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0073.fcs_tidied.csv
# output_name =  A10
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0074.fcs_tidied.csv
# output_name =  B10
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0075.fcs_tidied.csv
# output_name =  C10
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0076.fcs_tidied.csv
# output_name =  D10
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0077.fcs_tidied.csv
# output_name =  E10
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0078.fcs_tidied.csv
# output_name =  F10
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0079.fcs_tidied.csv
# output_name =  G10
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0080.fcs_tidied.csv
# output_name =  H10
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0081.fcs_tidied.csv
# output_name =  A11
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0082.fcs_tidied.csv
# output_name =  B11
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0083.fcs_tidied.csv
# output_name =  C11
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0084.fcs_tidied.csv
# output_name =  D11
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0085.fcs_tidied.csv
# output_name =  E11
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0086.fcs_tidied.csv
# output_name =  F11
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0087.fcs_tidied.csv
# output_name =  G11
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0088.fcs_tidied.csv
# output_name =  H11
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0089.fcs_tidied.csv
# output_name =  A12
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0090.fcs_tidied.csv
# output_name =  B12
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0091.fcs_tidied.csv
# output_name =  C12
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0092.fcs_tidied.csv
# output_name =  D12
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0093.fcs_tidied.csv
# output_name =  E12
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0094.fcs_tidied.csv
# output_name =  F12
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0095.fcs_tidied.csv
# output_name =  G12
# file_name =  ../Data/Flow/181010_HCK_dif_burden_G4/tidy/RMM2018-10-10.0096.fcs_tidied.csv
# output_name =  H12
# 53.521552085876465
